# %% [markdown]
# <a href="https://colab.research.google.com/github/nisharonn/US-Economic-Recovery-Post-COVID-19/blob/main/MLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multiple Logistic Regression
#
# **Goal:** Build a binary **multiple logistic regression** model to predict employment recovery [**`emp recovered`** (0 = net change < 0, 1 = net change >= 0)] from predictors. Predict which states are expected to make a full recovery in employment after 5 years.

# %% [markdown]
# ## 0) Setup (imports)

# %%
# !pip install -q ISLP statsmodels scikit-learn pandas numpy matplotlib
# !pip install seaborn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Logit
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve


pd.set_option("display.width", 140)
pd.set_option("display.max_columns", 120)
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.12/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %% [markdown]
# ## 0) Load Dataset

# %%
data = pd.read_csv('data.csv')
print(data.shape)
data.head()
# Out:
# (3519, 54)
#   statename  year  month  spend apparel and accessories  spend accommodation and food services  spend arts, entertainment, and recreation  \
# 0   Alabama  2020      1                         0.0000                          -1.910000e-09                                     0.0000
# 1   Alabama  2020      2                        -0.0438                           2.160000e-02                                     0.0643
# 2   Alabama  2020      3                        -0.3510                          -3.800000e-01                                    -0.3730
# 3   Alabama  2020      4                        -0.5350                          -6.060000e-01                                    -0.6520
# 4   Alabama  2020      5                        -0.1820                          -3.820000e-01                                    -0.4720
#
#    spend all  spend general merchandise + apparel  spend durable goods  spend general merchandise  spend grocery and food stores  \
# 0     0.0000                        -2.880000e-08         3.280000e-08                     0.0000                         0.0000
# 1     0.0278                         2.020000e-02         1.250000e-02                     0.0782                         0.0935
# 2    -0.0898                        -1.460000e-01        -3.850000e-02                     0.0646                         0.3740
# 3    -0.2290                        -3.190000e-01         1.530000e-02                    -0.0916                         0.1650
# 4    -0.1010                        -7.270000e-02         1.720000e-01                     0.0279                         0.1500
#
#    spend health care and social assistance  spend home improvement centers  spend other in-person services  spend non-durable goods  \
# 0                             3.870000e-08                          0.0000                          0.0000             8.600000e-08
# 1                            -1.310000e-02                          0.0341                         -0.0368             2.490000e-02
# 2                            -1.610000e-01                          0.0591                         -0.1770             1.830000e-02
# 3                            -5.770000e-01                          0.2300                         -0.4660            -1.700000e-01
# 4                            -2.450000e-01                          0.3840                         -0.1990            -5.330000e-02
#
#    spend remote services  spend transportation and warehousing  spend all_incmiddle  spend all q1  spend all q2  spend all q3  \
# 0          -6.630000e-09                                0.0000         8.100000e-08        0.0000        0.0000        0.0000
# 1           4.500000e-02                               -0.0412         8.730000e-03        0.0514       -0.0106        0.0348
# 2          -2.870000e-02                               -0.4600        -1.050000e-01       -0.0571       -0.1090       -0.0996
# 3          -1.210000e-01                               -0.6440        -2.620000e-01       -0.1630       -0.2700       -0.2520
# 4          -5.080000e-02                               -0.6160        -1.330000e-01       -0.0346       -0.1550       -0.1030
#
#    spend all q4  spend in-person services  spend retail excluding grocery  spend retail including grocery  day_endofweek  emp all  \
# 0        0.0000             -3.680000e-08                   -4.440000e-08                    4.360000e-08           31.0 -0.00474
# 1        0.0408              2.190000e-04                    2.340000e-02                    5.010000e-02           28.0  0.01510
# 2       -0.1080             -3.280000e-01                   -8.410000e-02                    8.000000e-02           27.0 -0.09350
# 3       -0.2620             -5.840000e-01                   -1.450000e-01                   -3.380000e-02           24.0 -0.21500
# 4       -0.1400             -3.680000e-01                    1.160000e-01                    1.290000e-01           29.0 -0.17200
#
#     emp q1   emp q2   emp q3   emp q4  emp inc middle  emp inc below_median  emp inc above median  emp trade_transport utilities  \
# 0 -0.01700  0.00717 -0.00084 -0.00768         0.00311              -0.00574              -0.00343                        -0.0355
# 1  0.00845  0.01100  0.02940  0.01040         0.02030               0.00962               0.02220                         0.0163
# 2 -0.19800 -0.07090 -0.03170 -0.03860        -0.05100              -0.13900              -0.03430                        -0.1420
# 3 -0.41300 -0.18600 -0.10800 -0.07350        -0.14700              -0.30700              -0.09520                        -0.2700
# 4 -0.30000 -0.13100 -0.13200 -0.06780        -0.13100              -0.22100              -0.10700                        -0.2040
#
#    emp professional business_services  emp education health services  emp leisure hospitality   case_rate  death_rate  test_rate  \
# 0                            -0.00263                         0.0107                  -0.0168         NaN         NaN        NaN
# 1                            -0.00342                         0.0505                  -0.0200         NaN         NaN        NaN
# 2                            -0.05530                        -0.0833                  -0.3190    3.848895    0.017158        NaN
# 3                            -0.17100                        -0.2360                  -0.5410   72.970000    2.257533        NaN
# 4                            -0.28300                        -0.1220                  -0.2460  224.387097    8.786129        NaN
#
#    vaccine_rate  fullvaccine_rate  booster_first_rate  hospitalized_rate   day  time retail and recreation  time grocery and pharmacy  \
# 0           NaN               NaN                 NaN                NaN   NaN                         NaN                        NaN
# 1           NaN               NaN                 NaN                NaN  29.0                      0.0900                     0.0414
# 2           NaN               NaN                 NaN           0.101591  31.0                     -0.3340                    -0.0643
# 3           NaN               NaN                 NaN           7.704000  30.0                     -0.2400                    -0.0300
# 4           NaN               NaN                 NaN           8.569677  31.0                     -0.0914                     0.0314
#
#    time parks  time transit stations  time workplaces  time residential  time away from home emp recovered
# 0         NaN                    NaN              NaN               NaN                  NaN         False
# 1       0.191                 0.1070            0.010          -0.00571              0.00855          True
# 2       0.180                -0.2340           -0.344           0.13100             -0.15900         False
# 3       0.143                -0.2300           -0.347           0.12100             -0.14800         False
# 4       0.373                -0.0371           -0.236           0.08290             -0.09430         False

# %%
data.columns
# Out:
# Index(['statename', 'year', 'month', 'spend apparel and accessories', 'spend accommodation and food services',
#        'spend arts, entertainment, and recreation', 'spend all', 'spend general merchandise + apparel', 'spend durable goods',
#        'spend general merchandise', 'spend grocery and food stores', 'spend health care and social assistance',
#        'spend home improvement centers', 'spend other in-person services', 'spend non-durable goods', 'spend remote services',
#        'spend transportation and warehousing', 'spend all_incmiddle', 'spend all q1', 'spend all q2', 'spend all q3', 'spend all q4',
#        'spend in-person services', 'spend retail excluding grocery', 'spend retail including grocery', 'day_endofweek', 'emp all',
#        'emp q1', 'emp q2', 'emp q3', 'emp q4', 'emp inc middle', 'emp inc below_median', 'emp inc above median',
#        'emp trade_transport utilities', 'emp professional business_services', 'emp education health services', 'emp leisure hospitality',
#        'case_rate', 'death_rate', 'test_rate', 'vaccine_rate', 'fullvaccine_rate', 'booster_first_rate', 'hospitalized_rate', 'day',
# min                    -0.331000    -0.669000              -0.757000        -0.634000         -0.018600            -0.294000
# 25%                    -0.068600     0.013600              -0.291000        -0.306000          0.032900            -0.102000
# 50%                    -0.012900     0.340000              -0.140000        -0.240000          0.054300            -0.060900
# 75%                     0.042900     0.891500               0.025700        -0.183000          0.087850            -0.034050
# max                     0.444000     4.760000               0.786000         0.060000          0.241000             0.031300

# %% [markdown]
# ## 1) EDA

# %%
# Remove irrelevant temporal predictors
data = data.drop(columns=['day_endofweek', 'time retail and recreation', 'time grocery and pharmacy', 'time parks', 'time transit stations', 'time workplaces',
       'time residential', 'time away from home', 'day'])

# Use numerical features for EDA
num_cols = data.select_dtypes(include=['float64', 'int64']).columns

data.columns
# Out:
# Index(['statename', 'year', 'month', 'spend apparel and accessories', 'spend accommodation and food services',
#        'spend arts, entertainment, and recreation', 'spend all', 'spend general merchandise + apparel', 'spend durable goods',
#        'spend general merchandise', 'spend grocery and food stores', 'spend health care and social assistance',
#        'spend home improvement centers', 'spend other in-person services', 'spend non-durable goods', 'spend remote services',
#        'spend transportation and warehousing', 'spend all_incmiddle', 'spend all q1', 'spend all q2', 'spend all q3', 'spend all q4',
#        'spend in-person services', 'spend retail excluding grocery', 'spend retail including grocery', 'emp all', 'emp q1', 'emp q2',
#        'emp q3', 'emp q4', 'emp inc middle', 'emp inc below_median', 'emp inc above median', 'emp trade_transport utilities',
#        'emp professional business_services', 'emp education health services', 'emp leisure hospitality', 'case_rate', 'death_rate',
#        'test_rate', 'vaccine_rate', 'fullvaccine_rate', 'booster_first_rate', 'hospitalized_rate', 'emp recovered'],
#       dtype='object')

# %%
import seaborn as sns
correlation_matrix = data[num_cols].corr()
# Create a heatmap
plt.figure(figsize=(12, 10))
ax = sns.heatmap(
    correlation_matrix,
    cmap="coolwarm",
    center=0,
    xticklabels=correlation_matrix.columns,
    yticklabels=correlation_matrix.columns
)

# Rotate labels for readability
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.title('Correlation Matrix Heatmap')
plt.tight_layout()
plt.show()

# %%
print(data['year'].unique())
# Out:
# [2020 2021 2022 2023 2024 2025]

# %%
# select features and target
feat = ['spend durable goods', 'spend home improvement centers', 'spend grocery and food stores',
        'booster_first_rate', 'hospitalized_rate'
       ]
target = 'emp recovered'


df_25 = data[(data['month'] == 1) & (data['year'] == 2025)].dropna()
print(df_25[feat + [target]].isnull().sum())
# Out:
# spend durable goods               0
# spend home improvement centers    0
# spend grocery and food stores     0
# booster_first_rate                0
# hospitalized_rate                 0
# emp recovered                     0
# dtype: int64

# %% [markdown]
# # ***Variant 1: Change # of predictors***
#
# ## **Two COVID Predictors**

# %% [markdown]
# ## 2) Prepare data for fitting
# - **Predictors:** ['spend home improvement centers', 'spend grocery and food stores', 'spend home improvement centers', 'booster_first_rate, 'hospitalized_rate']

# %%
# see missing values in features and target
print(f'num missing in cols: \n{data[feat + [target]].isnull().sum()}')
# Out:
# num missing in cols:
# spend durable goods                  0
# spend home improvement centers       0
# spend grocery and food stores        0
# booster_first_rate                1122
# hospitalized_rate                  130
# emp recovered                      239
# dtype: int64

# %%
# drop rows with missing values
data = data.dropna(subset=feat + [target])

# store statenames for mapping later
state_names = data['statename']

# define X and y
X = data[feat]
y = data[target].astype(int)

X.head()

print(f'num missing in cols: \n{data[feat + [target]].isnull().sum()}')
print(f'\ndata points and predictors: {data.shape}')
# Out:
# num missing in cols:
# spend durable goods               0
# spend home improvement centers    0
# spend grocery and food stores     0
# booster_first_rate                0
# hospitalized_rate                 0
# emp recovered                     0
# dtype: int64
#
# data points and predictors: (2209, 45)

# %% [markdown]
# **Split the data**

# %%
# test set is all data from january 2025 (five years after the start of the pandemic)
test_mask = (data['year'] == 2025) & (data['month'] == 1)
X_test = X[test_mask]
y_test = y[test_mask]
states_test = state_names[test_mask]

# train set is all other data
X_train = X[~test_mask]
y_train = y[~test_mask]
states_train = state_names[~test_mask]

# print lengths of train and test sets
print(f'train set length: {len(X_train)}')
print(f'test set length: {len(X_test)}')
# Out:
# train set length: 2159
# test set length: 50

# %% [markdown]
# ## 3) Fit logistic regression with **`statsmodels.Logit`**
#
# 1. Fit: `Logit(y_train, X).fit(...)`.
# 2. Print the summary.
# 3. Compute **odds ratios** by exponentiating the coefficients

# %%
X = sm.add_constant(X_train, has_constant='add')
logit_mod = Logit(y_train, X).fit()

print(logit_mod.summary()) # print summary
print(np.exp(logit_mod.params)) # print the exponentiated coefficients
# Out:
# Optimization terminated successfully.
#          Current function value: 0.589222
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          emp recovered   No. Observations:                 2159
# Model:                          Logit   Df Residuals:                     2153
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 23 Nov 2025   Pseudo R-squ.:                 0.04752
# Time:                        07:41:28   Log-Likelihood:                -1272.1
# converged:                       True   LL-Null:                       -1335.6
# Covariance Type:            nonrobust   LLR p-value:                 1.058e-25
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             -0.3155      0.180     -1.750      0.080      -0.669       0.038
# spend durable goods                5.5326      0.638      8.665      0.000       4.281       6.784
# spend home improvement centers    -1.7717      0.333     -5.316      0.000      -2.425      -1.119
# spend grocery and food stores      0.0248      0.542      0.046      0.964      -1.038       1.088
# booster_first_rate                -0.0265      0.005     -5.605      0.000      -0.036      -0.017
# hospitalized_rate                 -0.0029      0.002     -1.187      0.235      -0.008       0.002
# ==================================================================================================
# const                               0.729414
# spend durable goods               252.803238
# spend home improvement centers      0.170037
# spend grocery and food stores       1.025084
# booster_first_rate                  0.973862
# hospitalized_rate                   0.997055
# dtype: float64

# %% [markdown]
# ## 4) Predict & **assess with Accuracy and ROC/AUC** (test) using **`sklearn`**
#
# **Steps:**
# 1. Fit a `LogisticRegression` on `X_train, y_train`.
# 2. Predict **test** labels and **test** probabilities.
# 3. Compute **accuracy (train/test)** and **ROC AUC (test)**. Print them.
# 4. Plot the **ROC curve**.

# %%
sk_log = LogisticRegression(max_iter=1000).fit(X_train, y_train)

yhat_tr = sk_log.predict(X_train) # (predict using train X)
yhat_te = sk_log.predict(X_test) # (predict using test X)
proba_te = sk_log.predict_proba(X_test)[:, 1] # predict status = 1 probabilities

baseline_rate = y_test.value_counts(normalize=True).max() # baseline rate for majority class accuracy
acc_tr = accuracy_score(y_train, yhat_tr) # (train accuracy)
acc_te = accuracy_score(y_test, yhat_te) # (test accuracy)
auc_te = roc_auc_score(y_test, proba_te) # (roc auc test score)

print("Naive baseline (majority class accuracy):", round(baseline_rate, 3))
print(f"Accuracy (train): {acc_tr:.3f}")
print(f"Accuracy (test): {acc_te:.3f}")
print(f"AUC (test):      {auc_te:.3f}")

fpr, tpr, thr = roc_curve(y_test, proba_te)
plt.figure()
plt.plot(fpr, tpr, label='ROC')
plt.plot([0,1],[0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve (test)')
plt.legend()
plt.show()
# Out:
# Naive baseline (majority class accuracy): 0.7
# Accuracy (train): 0.684
# Accuracy (test): 0.700
# AUC (test):      0.707

# %% [markdown]
# ## **All COVID Predictors**

# %% [markdown]
# ## 2) Prepare data for fitting
# - **Predictors:** use the same spend features, use all of COVID features

# %%
data2 = data.copy()

# %%
predictors = ['spend durable goods', 'spend home improvement centers', 'spend grocery and food stores', # spend features
              'case_rate', 'death_rate', 'test_rate', 'vaccine_rate', 'fullvaccine_rate', 'booster_first_rate', 'hospitalized_rate'] # covid features
data2 = data.dropna(subset=['emp recovered'] + predictors).copy()
data2.shape

state_names = data2['statename']
X = data2[predictors]
y = data2['emp recovered'].astype(int)

# %% [markdown]
# ## 3) Fit logistic regression with **`statsmodels.Logit`**
#
# 1. Fit: `Logit(y_train, X).fit(...)`.
# 2. Print the summary.
# 3. Compute **odds ratios** by exponentiating the coefficients

# %%
X = sm.add_constant(X_train, has_constant='add')
logit_mod = Logit(y_train, X).fit()

print(logit_mod.summary()) # print summary
print(np.exp(logit_mod.params)) # print the exponentiated coefficients
# Out:
# Optimization terminated successfully.
#          Current function value: 0.543415
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          emp recovered   No. Observations:                 2116
# Model:                          Logit   Df Residuals:                     2105
# Method:                           MLE   Df Model:                           10
# Date:                Sun, 23 Nov 2025   Pseudo R-squ.:                  0.1275
# Time:                        07:41:53   Log-Likelihood:                -1149.9
# converged:                       True   LL-Null:                       -1317.9
# Covariance Type:            nonrobust   LLR p-value:                 3.458e-66
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              1.3547      0.866      1.565      0.118      -0.342       3.052
# spend durable goods                4.9330      0.726      6.794      0.000       3.510       6.356
# spend home improvement centers    -0.5760      0.373     -1.543      0.123      -1.308       0.156
# spend grocery and food stores     -0.6527      0.586     -1.113      0.266      -1.802       0.496
# case_rate                          0.0001   1.31e-05      8.671      0.000    8.79e-05       0.000
# death_rate                        -0.0037      0.001     -4.875      0.000      -0.005      -0.002
# test_rate                      -2.178e-06   5.21e-07     -4.180      0.000    -3.2e-06   -1.16e-06
# vaccine_rate                       0.0516      0.014      3.609      0.000       0.024       0.080
# fullvaccine_rate                  -0.1349      0.030     -4.515      0.000      -0.193      -0.076
# booster_first_rate                 0.0253      0.015      1.736      0.083      -0.003       0.054
# hospitalized_rate                 -0.0001      0.003     -0.044      0.965      -0.006       0.005
# ==================================================================================================
# const                               3.875514
# spend durable goods               138.794074
# spend home improvement centers      0.562146
# spend grocery and food stores       0.520634
# case_rate                           1.000114
# death_rate                          0.996293
# test_rate                           0.999998
# vaccine_rate                        1.052948
# fullvaccine_rate                    0.873846
# booster_first_rate                  1.025597
# hospitalized_rate                   0.999878
# dtype: float64

# %% [markdown]
# ## 4) Predict & **assess with Accuracy and ROC/AUC** (test) using **`sklearn`**
#
# **Steps:**
# 1. Fit a `LogisticRegression` on `X_train, y_train`.
# 2. Predict **test** labels and **test** probabilities.
# 3. Compute **accuracy (train/test)** and **ROC AUC (test)**. Print them.
# 4. Plot the **ROC curve**.

# %%
sk_log = LogisticRegression(max_iter=1000).fit(X_train, y_train)

yhat_tr = sk_log.predict(X_train) # (predict using train X)
yhat_te = sk_log.predict(X_test) # (predict using test X)
proba_te = sk_log.predict_proba(X_test)[:, 1] # predict emp recovery = 1 probabilities

baseline_rate = y_test.value_counts(normalize=True).max() # baseline rate for majority class accuracy
acc_tr = accuracy_score(y_train, yhat_tr) # (train accuracy)
acc_te = accuracy_score(y_test, yhat_te) # (test accuracy)
auc_te = roc_auc_score(y_test, proba_te) # (roc auc test score)

print("Naive baseline (majority class accuracy):", round(baseline_rate, 3))
print(f"Accuracy (train): {acc_tr:.3f}")
print(f"Accuracy (test): {acc_te:.3f}")
print(f"AUC (test):      {auc_te:.3f}")

fpr, tpr, thr = roc_curve(y_test, proba_te)
plt.figure()
plt.plot(fpr, tpr, label='ROC')
plt.plot([0,1],[0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve (test)')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Naive baseline (majority class accuracy): 0.694
# Accuracy (train): 0.724
# Accuracy (test): 0.735
# AUC (test):      0.753

# %% [markdown]
# # ***Variant 2: Standardize data variant***

# %%
data3 = data.copy()

# %%
predictors = ['spend durable goods', 'spend home improvement centers', 'spend grocery and food stores', # spend features
              'case_rate', 'death_rate', 'test_rate', 'vaccine_rate', 'fullvaccine_rate', 'booster_first_rate', 'hospitalized_rate'] # covid features
data3 = data.dropna(subset=['emp recovered'] + predictors).copy()
data3.shape

state_names = data3['statename']
X = data3[predictors]
y = data3['emp recovered'].astype(int)

# %%
# test set is all data from january 2025 (five years after the start of the pandemic)
test_mask = (data3['year'] == 2025) & (data3['month'] == 1)
X_test = X[test_mask]
y_test = y[test_mask]
states_test = state_names[test_mask]

# train set is all other data
X_train = X[~test_mask]
y_train = y[~test_mask]
states_train = state_names[~test_mask]

# print lengths of train and test sets
print(f'train set length: {len(X_train)}')
print(f'test set length: {len(X_test)}')
# Out:
# train set length: 2116
# test set length: 49

# %%
# standardize predictors
scaler = StandardScaler().fit(X_train[feat])
X_train = pd.DataFrame(scaler.transform(X_train[feat]), columns=feat, index=X_train.index)
X_test  = pd.DataFrame(scaler.transform(X_test[feat]), columns=feat, index=X_test.index)

# %%
X = sm.add_constant(X_train, has_constant='add')
logit_mod = Logit(y_train, X).fit()

print(logit_mod.summary()) # print summary
print(np.exp(logit_mod.params)) # print the exponentiated coefficients
# Out:
# Optimization terminated successfully.
#          Current function value: 0.589687
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          emp recovered   No. Observations:                 2116
# Model:                          Logit   Df Residuals:                     2110
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 23 Nov 2025   Pseudo R-squ.:                 0.05324
# Time:                        08:01:46   Log-Likelihood:                -1247.8
# converged:                       True   LL-Null:                       -1317.9
# Covariance Type:            nonrobust   LLR p-value:                 1.527e-28
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             -0.8416      0.050    -16.968      0.000      -0.939      -0.744
# spend durable goods                0.6146      0.071      8.620      0.000       0.475       0.754
# spend home improvement centers    -0.3665      0.069     -5.308      0.000      -0.502      -0.231
# spend grocery and food stores      0.0469      0.052      0.895      0.371      -0.056       0.150
# booster_first_rate                -0.3393      0.052     -6.531      0.000      -0.441      -0.237
# hospitalized_rate                 -0.0705      0.051     -1.375      0.169      -0.171       0.030
# ==================================================================================================
# const                             0.431008
# spend durable goods               1.848844
# spend home improvement centers    0.693135
# spend grocery and food stores     1.048007
# booster_first_rate                0.712262
# hospitalized_rate                 0.931949
# dtype: float64

# %%
sk_log = LogisticRegression(max_iter=1000).fit(X_train, y_train)

yhat_tr = sk_log.predict(X_train) # (predict using train X)
yhat_te = sk_log.predict(X_test) # (predict using test X)
proba_te = sk_log.predict_proba(X_test)[:, 1] # predict emp recovery = 1 probabilities

baseline_rate = y_test.value_counts(normalize=True).max() # baseline rate for majority class accuracy
acc_tr = accuracy_score(y_train, yhat_tr) # (train accuracy)
acc_te = accuracy_score(y_test, yhat_te) # (test accuracy)
auc_te = roc_auc_score(y_test, proba_te) # (roc auc test score)

print("Naive baseline (majority class accuracy):", round(baseline_rate, 3))
print(f"Accuracy (train): {acc_tr:.3f}")
print(f"Accuracy (test): {acc_te:.3f}")
print(f"AUC (test):      {auc_te:.3f}")

fpr, tpr, thr = roc_curve(y_test, proba_te)
plt.figure()
plt.plot(fpr, tpr, label='ROC')
plt.plot([0,1],[0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve (test)')
plt.legend()
plt.show()
# Out:
# Naive baseline (majority class accuracy): 0.694
# Accuracy (train): 0.674
# Accuracy (test): 0.694
# AUC (test):      0.706

# %% [markdown]
# # ***Variant 3: Add interaction terms***

# %%
data4 = data.copy()

# %%
predictors = ['spend durable goods', 'spend home improvement centers', 'spend grocery and food stores', 'spend in-person services', # spend features
              'emp education health services', 'emp leisure hospitality', # emp features
              'case_rate', 'death_rate', 'test_rate', 'vaccine_rate', 'fullvaccine_rate', 'booster_first_rate', 'hospitalized_rate'] # covid features
data4 = data.dropna(subset=['emp recovered'] + predictors).copy()
data4.shape

state_names = data4['statename']
X = data4[predictors]
y = data4['emp recovered'].astype(int)

# %%
# test set is all data from january 2025 (five years after the start of the pandemic)
test_mask = (data4['year'] == 2025) & (data4['month'] == 1)
X_test = X[test_mask]
y_test = y[test_mask]
states_test = state_names[test_mask]

# train set is all other data
X_train = X[~test_mask]
y_train = y[~test_mask]
states_train = state_names[~test_mask]

# print lengths of train and test sets
print(f'train set length: {len(X_train)}')
print(f'test set length: {len(X_test)}')
# Out:
# train set length: 1978
# test set length: 46

# %%
# X_train.loc[:, 'hospitalized_rate_x_emp education health services'] = (
#     X_train['hospitalized_rate'] * X_train['emp education health services']
# )
# X_test.loc[:, 'hospitalized_rate_x_emp education health services'] = (
#     X_test['hospitalized_rate'] * X_test['emp education health services']
# )

# %%
X_train['spend_inperson_x_emp_leisure'] = (
    X_train['spend in-person services'] * X_train['emp leisure hospitality']
)
X_test['spend_inperson_x_emp_leisure'] = (
    X_test['spend in-person services'] * X_test['emp leisure hospitality']
)
# Out:
# /tmp/ipython-input-3907299632.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['spend_inperson_x_emp_leisure'] = (
# /tmp/ipython-input-3907299632.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['spend_inperson_x_emp_leisure'] = (

# %%
X = sm.add_constant(X_train, has_constant='add')
logit_mod = Logit(y_train, X).fit()

print(logit_mod.summary()) # print summary
print(np.exp(logit_mod.params)) # print the exponentiated coefficients
# Out:
# Optimization terminated successfully.
#          Current function value: 0.212626
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          emp recovered   No. Observations:                 1978
# Model:                          Logit   Df Residuals:                     1963
# Method:                           MLE   Df Model:                           14
# Date:                Sun, 23 Nov 2025   Pseudo R-squ.:                  0.6379
# Time:                        08:09:46   Log-Likelihood:                -420.57
# converged:                       True   LL-Null:                       -1161.5
# Covariance Type:            nonrobust   LLR p-value:                3.833e-308
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              5.3181      1.537      3.461      0.001       2.306       8.330
# spend durable goods               -0.1828      1.516     -0.121      0.904      -3.154       2.788
# spend home improvement centers     0.6423      0.714      0.900      0.368      -0.757       2.041
# spend grocery and food stores     -2.1007      1.167     -1.800      0.072      -4.388       0.186
# spend in-person services           0.7610      1.161      0.655      0.512      -1.515       3.037
# emp education health services     19.0236      1.145     16.614      0.000      16.779      21.268
# emp leisure hospitality           15.2733      1.550      9.857      0.000      12.236      18.310
# case_rate                          0.0002   2.05e-05      9.924      0.000       0.000       0.000
# death_rate                        -0.0104      0.001     -7.424      0.000      -0.013      -0.008
# test_rate                       6.299e-06   1.06e-06      5.948      0.000    4.22e-06    8.37e-06
# vaccine_rate                       0.0592      0.027      2.192      0.028       0.006       0.112
# fullvaccine_rate                  -0.1838      0.054     -3.373      0.001      -0.291      -0.077
# booster_first_rate                -0.0092      0.025     -0.367      0.714      -0.058       0.040
# hospitalized_rate                  0.0103      0.005      1.927      0.054      -0.000       0.021
# spend_inperson_x_emp_leisure      -1.6366      6.234     -0.263      0.793     -13.856      10.582
# ==================================================================================================
# const                             2.039926e+02
# spend durable goods               8.329243e-01
# spend home improvement centers    1.900882e+00
# spend grocery and food stores     1.223685e-01
# spend in-person services          2.140402e+00
# emp education health services     1.827522e+08
# emp leisure hospitality           4.296549e+06
# case_rate                         1.000204e+00
# death_rate                        9.896762e-01
# test_rate                         1.000006e+00
# vaccine_rate                      1.060957e+00
# fullvaccine_rate                  8.321199e-01
# booster_first_rate                9.908516e-01
# hospitalized_rate                 1.010311e+00
# spend_inperson_x_emp_leisure      1.946389e-01
# dtype: float64

# %%
sk_log = LogisticRegression(max_iter=1000).fit(X_train, y_train)

yhat_tr = sk_log.predict(X_train) # (predict using train X)
yhat_te = sk_log.predict(X_test) # (predict using test X)
proba_te = sk_log.predict_proba(X_test)[:, 1] # predict emp recovery = 1 probabilities

baseline_rate = y_test.value_counts(normalize=True).max() # baseline rate for majority class accuracy
acc_tr = accuracy_score(y_train, yhat_tr) # (train accuracy)
acc_te = accuracy_score(y_test, yhat_te) # (test accuracy)
auc_te = roc_auc_score(y_test, proba_te) # (roc auc test score)

print("Naive baseline (majority class accuracy):", round(baseline_rate, 3))
print(f"Accuracy (train): {acc_tr:.3f}")
print(f"Accuracy (test): {acc_te:.3f}")
print(f"AUC (test):      {auc_te:.3f}")

fpr, tpr, thr = roc_curve(y_test, proba_te)
plt.figure()
plt.plot(fpr, tpr, label='ROC')
plt.plot([0,1],[0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve (test)')
plt.legend()
plt.show()
# Out:
# Naive baseline (majority class accuracy): 0.739
# Accuracy (train): 0.899
# Accuracy (test): 0.870
# AUC (test):      0.951
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
